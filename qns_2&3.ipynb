# %%
#vader dom
import pandas as pd
from scipy import stats

# Load your data
data = pd.read_csv('/content/vadertextblob.csv')

# List of airlines to test
airlines = ['Frontier', 'Silver', 'Jetblue Airways']

# Initialize a dictionary to store results
t_test_results = {}

# Loop through each airline and perform the tests
for airline in airlines:
    # Filter for current airline's negative domestic flights
    airline_filter = (data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                     (data['flight_type'] == 'Domestic')
    airline_data = data[airline_filter]
    airline_avg_sentiment = airline_data['compound_vader'].mean()
    airline_obs = len(airline_data)

    # Filter for other airlines' negative domestic flights
    other_airlines_filter = (~data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                            (data['flight_type'] == 'Domestic')

    other_airlines_data = data[other_airlines_filter]
    other_airlines_avg_sentiment = other_airlines_data['compound_vader'].mean()
    other_airlines_observations = len(other_airlines_data)

    # Perform t-test
    t_stat, p_value = stats.ttest_ind(airline_data['compound_vader'],
                                      other_airlines_data['compound_vader'],
                                      equal_var=False)

    # Calculate one-tail p-value
    one_tail_p_value = p_value / 2

    # Store results in the dictionary
    t_test_results[airline] = {
        't_stat': t_stat,
        'p_value': p_value,
        'one_tail_p_value': one_tail_p_value,
        'airline_obs': airline_obs,
        'other_airlines_observations': other_airlines_observations,
        'airline_avg_sentiment': airline_avg_sentiment,
        'other_airlines_avg_sentiment': other_airlines_avg_sentiment
    }

# Print the results
for airline, results in t_test_results.items():
    print(f"Results for {airline}:")
    print(f"Observations: {results['airline_obs']}")
    print(f"Average Sentiment: {results['airline_avg_sentiment']}")
    print(f"Other Airlines Observations: {results['other_airlines_observations']}")
    print(f"Other Airlines Average Sentiment: {results['other_airlines_avg_sentiment']}")
    print(f"T-Statistic: {results['t_stat']}")
    print(f"P-Value: {results['p_value']}")
    print(f"One-Tail P-Value: {results['one_tail_p_value']}")
    print("\n")  # Adds a newline for better readability
# Out:
# Results for Frontier:
# Observations: 73
# Average Sentiment: -0.2489767123287671
# Other Airlines Observations: 1146
# Other Airlines Average Sentiment: -0.076665445026178
# T-Statistic: -2.3378980752133636
# P-Value: 0.021785067368662186
# One-Tail P-Value: 0.010892533684331093
#
#
# Results for Silver:
# Observations: 74
# Average Sentiment: -0.2532851351351352
# Other Airlines Observations: 1145
# Other Airlines Average Sentiment: -0.07623650655021834
# T-Statistic: -2.4102828638897287
# P-Value: 0.01810324021684995
# One-Tail P-Value: 0.009051620108424975
#
#
# Results for Jetblue Airways:
# Observations: 70
# Average Sentiment: -0.3206657142857142
# Other Airlines Observations: 1149
# Other Airlines Average Sentiment: -0.07274786771105309
# T-Statistic: -3.3391513573452793
# P-Value: 0.0012794392276093817
# One-Tail P-Value: 0.0006397196138046908

# %%
#vader int
import pandas as pd
from scipy import stats

# Load your data
data = pd.read_csv('/content/vadertextblob.csv')

# List of airlines to test
airlines = ['United Airlines', 'Royal Jordanian', 'Interjet']

# Initialize a dictionary to store results
t_test_results = {}

# Loop through each airline and perform the tests
for airline in airlines:
    # Filter for current airline's negative domestic flights
    airline_filter = (data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                     (data['flight_type'] == 'International')
    airline_data = data[airline_filter]
    airline_avg_sentiment = airline_data['compound_vader'].mean()
    airline_obs = len(airline_data)

    # Filter for other airlines' negative domestic flights
    other_airlines_filter = (~data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                            (data['flight_type'] == 'International')

    other_airlines_data = data[other_airlines_filter]
    other_airlines_avg_sentiment = other_airlines_data['compound_vader'].mean()
    other_airlines_observations = len(other_airlines_data)

    # Perform t-test
    t_stat, p_value = stats.ttest_ind(airline_data['compound_vader'],
                                      other_airlines_data['compound_vader'],
                                      equal_var=False)

    # Calculate one-tail p-value
    one_tail_p_value = p_value / 2

    # Store results in the dictionary
    t_test_results[airline] = {
        't_stat': t_stat,
        'p_value': p_value,
        'one_tail_p_value': one_tail_p_value,
        'airline_obs': airline_obs,
        'other_airlines_observations': other_airlines_observations,
        'airline_avg_sentiment': airline_avg_sentiment,
        'other_airlines_avg_sentiment': other_airlines_avg_sentiment
    }

# Print the results
for airline, results in t_test_results.items():
    print(f"Results for {airline}:")
    print(f"Observations: {results['airline_obs']}")
    print(f"Average Sentiment: {results['airline_avg_sentiment']}")
    print(f"Other Airlines Observations: {results['other_airlines_observations']}")
    print(f"Other Airlines Average Sentiment: {results['other_airlines_avg_sentiment']}")
    print(f"T-Statistic: {results['t_stat']}")
    print(f"P-Value: {results['p_value']}")
    print(f"One-Tail P-Value: {results['one_tail_p_value']}")
    print("\n")  # Adds a newline for better readability
# Out:
# Results for United Airlines:
# Observations: 28
# Average Sentiment: -0.4150642857142857
# Other Airlines Observations: 1341
# Other Airlines Average Sentiment: 0.043078970917225956
# T-Statistic: -4.140990195035448
# P-Value: 0.0002776587242161543
# One-Tail P-Value: 0.00013882936210807715
#
#
# Results for Royal Jordanian:
# Observations: 22
# Average Sentiment: -0.3707636363636363
# Other Airlines Observations: 1347
# Other Airlines Average Sentiment: 0.04031469933184855
# T-Statistic: -3.3341138919547677
# P-Value: 0.0030057408865871243
# One-Tail P-Value: 0.0015028704432935621
#
#
# Results for Interjet:
# Observations: 32
# Average Sentiment: -0.326659375
# Other Airlines Observations: 1337
# Other Airlines Average Sentiment: 0.042333732236350036
# T-Statistic: -3.6153960561170884
# P-Value: 0.0009805113865084334
# One-Tail P-Value: 0.0004902556932542167

# %%
#textblob dom
import pandas as pd
from scipy import stats

# Load your data
data = pd.read_csv('/content/vadertextblob.csv')

# List of airlines to test
airlines = ['American Airlines', 'Spirit Airlines', 'United Airlines']

# Initialize a dictionary to store results
t_test_results = {}

# Loop through each airline and perform the tests
for airline in airlines:
    # Filter for current airline's negative domestic flights
    airline_filter = (data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                     (data['flight_type'] == 'Domestic')
    airline_data = data[airline_filter]
    airline_avg_sentiment = airline_data['Sentiment_tb'].mean()
    airline_obs = len(airline_data)

    # Filter for other airlines' negative domestic flights
    other_airlines_filter = (~data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                            (data['flight_type'] == 'Domestic')

    other_airlines_data = data[other_airlines_filter]
    other_airlines_avg_sentiment = other_airlines_data['Sentiment_tb'].mean()
    other_airlines_observations = len(other_airlines_data)

    # Perform t-test
    t_stat, p_value = stats.ttest_ind(airline_data['Sentiment_tb'],
                                      other_airlines_data['Sentiment_tb'],
                                      equal_var=False)

    # Calculate one-tail p-value
    one_tail_p_value = p_value / 2

    # Store results in the dictionary
    t_test_results[airline] = {
        't_stat': t_stat,
        'p_value': p_value,
        'one_tail_p_value': one_tail_p_value,
        'airline_obs': airline_obs,
        'other_airlines_observations': other_airlines_observations,
        'airline_avg_sentiment': airline_avg_sentiment,
        'other_airlines_avg_sentiment': other_airlines_avg_sentiment
    }

# Print the results
for airline, results in t_test_results.items():
    print(f"Results for {airline}:")
    print(f"Observations: {results['airline_obs']}")
    print(f"Average Sentiment: {results['airline_avg_sentiment']}")
    print(f"Other Airlines Observations: {results['other_airlines_observations']}")
    print(f"Other Airlines Average Sentiment: {results['other_airlines_avg_sentiment']}")
    print(f"T-Statistic: {results['t_stat']}")
    print(f"P-Value: {results['p_value']}")
    print(f"One-Tail P-Value: {results['one_tail_p_value']}")
    print("\n")  # Adds a newline for better readability
# Out:
# Results for American Airlines:
# Observations: 66
# Average Sentiment: -0.0523699103030303
# Other Airlines Observations: 1153
# Other Airlines Average Sentiment: 0.009095312773633998
# T-Statistic: -2.7900160297909697
# P-Value: 0.006595658795952108
# One-Tail P-Value: 0.003297829397976054
#
#
# Results for Spirit Airlines:
# Observations: 86
# Average Sentiment: -0.07982861102325582
# Other Airlines Observations: 1133
# Other Airlines Average Sentiment: 0.012264556130626656
# T-Statistic: -3.0685404521368156
# P-Value: 0.0028105248039815667
# One-Tail P-Value: 0.0014052624019907833
#
#
# Results for United Airlines:
# Observations: 60
# Average Sentiment: -0.08064232211666665
# Other Airlines Observations: 1159
# Other Airlines Average Sentiment: 0.010240742773943054
# T-Statistic: -2.4035593275459837
# P-Value: 0.019202504592032443
# One-Tail P-Value: 0.009601252296016221

# %%
#textblob int
import pandas as pd
from scipy import stats

# Load your data
data = pd.read_csv('/content/vadertextblob.csv')

# List of airlines to test
airlines = ['Jetblue','Volaris', 'Interjet']

# Initialize a dictionary to store results
t_test_results = {}

# Loop through each airline and perform the tests
for airline in airlines:
    # Filter for current airline's negative domestic flights
    airline_filter = (data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                     (data['flight_type'] == 'International')
    airline_data = data[airline_filter]
    airline_avg_sentiment = airline_data['Sentiment_tb'].mean()
    airline_obs = len(airline_data)

    # Filter for other airlines' negative domestic flights
    other_airlines_filter = (~data['Airline Name'].str.contains(airline, case=False, na=False)) & \
                            (data['flight_type'] == 'International')

    other_airlines_data = data[other_airlines_filter]
    other_airlines_avg_sentiment = other_airlines_data['Sentiment_tb'].mean()
    other_airlines_observations = len(other_airlines_data)

    # Perform t-test
    t_stat, p_value = stats.ttest_ind(airline_data['Sentiment_tb'],
                                      other_airlines_data['Sentiment_tb'],
                                      equal_var=False)

    # Calculate one-tail p-value
    one_tail_p_value = p_value / 2

    # Store results in the dictionary
    t_test_results[airline] = {
        't_stat': t_stat,
        'p_value': p_value,
        'one_tail_p_value': one_tail_p_value,
        'airline_obs': airline_obs,
        'other_airlines_observations': other_airlines_observations,
        'airline_avg_sentiment': airline_avg_sentiment,
        'other_airlines_avg_sentiment': other_airlines_avg_sentiment
    }

# Print the results
for airline, results in t_test_results.items():
    print(f"Results for {airline}:")
    print(f"Observations: {results['airline_obs']}")
    print(f"Average Sentiment: {results['airline_avg_sentiment']}")
    print(f"Other Airlines Observations: {results['other_airlines_observations']}")
    print(f"Other Airlines Average Sentiment: {results['other_airlines_avg_sentiment']}")
    print(f"T-Statistic: {results['t_stat']}")
    print(f"P-Value: {results['p_value']}")
    print(f"One-Tail P-Value: {results['one_tail_p_value']}")
    print("\n")  # Adds a newline for better readability
# Out:
# Results for Jetblue:
# Observations: 12
# Average Sentiment: -0.1717653855
# Other Airlines Observations: 1357
# Other Airlines Average Sentiment: 0.02540191831761238
# T-Statistic: -3.6103956770382957
# P-Value: 0.003929983615325551
# One-Tail P-Value: 0.0019649918076627753
#
#
# Results for Volaris:
# Observations: 22
# Average Sentiment: -0.08094671877272729
# Other Airlines Observations: 1347
# Other Airlines Average Sentiment: 0.025382365511507056
# T-Statistic: -1.6080989077379377
# P-Value: 0.12248448929080301
# One-Tail P-Value: 0.061242244645401504
#
#
# Results for Interjet:
# Observations: 32
# Average Sentiment: -0.135884486625
# Other Airlines Observations: 1337
# Other Airlines Average Sentiment: 0.027492537100224382
# T-Statistic: -3.295259248116337
# P-Value: 0.0024094347222777404
# One-Tail P-Value: 0.0012047173611388702
